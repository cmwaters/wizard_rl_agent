# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

import glob
import matplotlib.pyplot as plt
import tikzplotlib

from plotting import load_data
from plotting import plot_scalar
from plotting import print_infos
from scipy.signal import savgol_filter

# %% [markdown]
# ### Plot Settings
#
# is already specified in plotting.py, but can be overwritten here

# %%
plt.rcParams["figure.figsize"] = (16,9)

# %%
# see available styles
# print(plt.style.available)

# %%
plt.style.use('ggplot')

# %% [markdown]
# ### Plotting Example

# %%
# load data
data = load_data(25, load_histos=False)

# %%
print_infos(data)
# Out:
# ##### Agents #####
# TFAgentsPPOAgent
#
#
# ##### Summaries #####
#
#
# ### TFAgentsPPOAgent ###
#
#
# ## scalars ##
#
#
# 1_win_percentage (949 time steps)
# 2_score (949 time steps)
# 7_valid_rate (949 time steps)
# 5_predictor_loss (948 time steps)
# 3_predictor_acc (948 time steps)
# 6_prediction_differences (949 time steps)
# 4_predictor_acc_real (949 time steps)
# 7_overall_mean_predictions_0 (949 time steps)
# 8_correct_mean_predictions_0 (949 time steps)
# 9_incorrect_mean_predictions_0 (949 time steps)
# 7_overall_mean_predictions_1 (949 time steps)
# 8_correct_mean_predictions_1 (949 time steps)
# 9_incorrect_mean_predictions_1 (949 time steps)
# 7_overall_mean_predictions_2 (949 time steps)
# 8_correct_mean_predictions_2 (949 time steps)
# 9_incorrect_mean_predictions_2 (949 time steps)
# 7_overall_mean_predictions_3 (949 time steps)
# 8_correct_mean_predictions_3 (949 time steps)
# 9_incorrect_mean_predictions_3 (949 time steps)
# 7_overall_mean_predictions_4 (949 time steps)
# 8_correct_mean_predictions_4 (949 time steps)
# 9_incorrect_mean_predictions_4 (949 time steps)
# 7_overall_mean_predictions_5 (949 time steps)
# 8_correct_mean_predictions_5 (949 time steps)
# 9_incorrect_mean_predictions_5 (949 time steps)
# 7_overall_mean_predictions_6 (949 time steps)
# 8_correct_mean_predictions_6 (949 time steps)
# 9_incorrect_mean_predictions_6 (949 time steps)
# 7_overall_mean_predictions_7 (949 time steps)
# 8_correct_mean_predictions_7 (949 time steps)
# 9_incorrect_mean_predictions_7 (949 time steps)
# 7_overall_mean_predictions_8 (949 time steps)
# 8_correct_mean_predictions_8 (949 time steps)
# 9_incorrect_mean_predictions_8 (949 time steps)
# 7_overall_mean_predictions_9 (949 time steps)
# 8_correct_mean_predictions_9 (949 time steps)
# 9_incorrect_mean_predictions_9 (949 time steps)
# 7_overall_mean_predictions_10 (949 time steps)
# 8_correct_mean_predictions_10 (949 time steps)
# 9_incorrect_mean_predictions_10 (949 time steps)
# 7_overall_mean_predictions_11 (949 time steps)
# 8_correct_mean_predictions_11 (949 time steps)
# 9_incorrect_mean_predictions_11 (949 time steps)
# 7_overall_mean_predictions_12 (949 time steps)
# 8_correct_mean_predictions_12 (949 time steps)
# 9_incorrect_mean_predictions_12 (949 time steps)
# 7_overall_mean_predictions_13 (949 time steps)
# 8_correct_mean_predictions_13 (949 time steps)
# 9_incorrect_mean_predictions_13 (949 time steps)
# 7_overall_mean_predictions_14 (949 time steps)
# 8_correct_mean_predictions_14 (949 time steps)
# 9_incorrect_mean_predictions_14 (949 time steps)
# 7_overall_mean_predictions_15 (949 time steps)
# 8_correct_mean_predictions_15 (949 time steps)
# 9_incorrect_mean_predictions_15 (949 time steps)

# %%
plot_scalar(data, summary_name='2_score',smoothing=True, smoothing_factor=0.7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-48ccbb371218> in <module>
# ----> 1 plot_scalar(data, summary_name='2_score',smoothing=True, smoothing_factor=0.7)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Plotting for Poster

# %%
vs_old_log_path = '/home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/train_vs_old/'
vs_current_log_path = '/home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/train_vs_current/'
evaluation_vs_old = '/home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/evaluate_vs_old/'
evaluation_vs_current = '/home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/evaluate_vs_current/'

# %%
evaluation_vs_old_2 = '/home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/evaluate_vs_current_2/4'

# %%
time_range = [0,60000]

# %% [markdown]
# ### load data

# %%
train_vs_old_data = load_data(1, load_histos=False, log_path = vs_old_log_path, time_range=time_range)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0706 17:10:33.420580 140514454599488 deprecation_wrapper.py:118] From /home/kaijeggle/dev/Uni/rL_project/Wizard/tests/plotting/plotting.py:42: The name tf.train.summary_iterator is deprecated. Please use tf.compat.v1.train.summary_iterator instead.
#
# W0706 17:10:33.421292 140514454599488 deprecation.py:323] From /home/kaijeggle/dev/Uni/rL_project/wizard_python/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# files are loaded from paths /home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/train_vs_old/*A*

# %%
train_vs_current_data = load_data(1, load_histos=False, log_path = vs_old_log_path, time_range=time_range)
# Out:
# files are loaded from paths /home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/train_vs_old/*A*

# %%
evaluate_vs_current_data = load_data(1, load_histos=False, log_path = evaluation_vs_current, time_range=time_range)
# Out:
# files are loaded from paths /home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/evaluate_vs_current/*A*

# %%
evaluate_vs_old_data = load_data(1, load_histos=False, log_path = evaluation_vs_old, time_range=time_range)
# Out:
# files are loaded from paths /home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/evaluate_vs_old/*A*

# %%
evaluate_vs_old_data_2 = load_data(1, load_histos=False, log_path = evaluation_vs_old_2, time_range=time_range)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0708 14:09:55.015570 139805563512640 deprecation_wrapper.py:118] From /home/kaijeggle/dev/Uni/rL_project/Wizard/tests/plotting/plotting.py:49: The name tf.train.summary_iterator is deprecated. Please use tf.compat.v1.train.summary_iterator instead.
#
# W0708 14:09:55.017871 139805563512640 deprecation.py:323] From /home/kaijeggle/dev/Uni/rL_project/wizard_python/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# files are loaded from paths /home/kaijeggle/Documents/Uni/TUB/Courses/NI_Project/evaluate_vs_current_2/4/*A*

# %%
print_infos(evaluate_vs_old_data_2)
# Out:
# ##### Agents #####
# AverageRandomPlayer
# RuleBasedAgent
# RuleBasedAgentPredictor
# TFAgentsPPOAgent
#
#
# ##### Summaries #####
#
#
# ### AverageRandomPlayer ###
#
#
# ## scalars ##
#
#
# 1_win_percentage (649 time steps)
# 2_score (649 time steps)
#
#
# ### RuleBasedAgent ###
#
#
# ## scalars ##
#
#
# 1_win_percentage (426 time steps)
# 2_score (426 time steps)
#
#
# ### RuleBasedAgentPredictor ###
#
#
# ## scalars ##
#
#
# 1_win_percentage (649 time steps)
# 2_score (649 time steps)
# 5_predictor_loss (582 time steps)
# 3_predictor_acc (582 time steps)
# 6_prediction_differences (649 time steps)
# 4_predictor_acc_real (649 time steps)
# 7_overall_mean_predictions_0 (649 time steps)
# 8_correct_mean_predictions_0 (649 time steps)
# 9_incorrect_mean_predictions_0 (649 time steps)
# 7_overall_mean_predictions_1 (649 time steps)
# 8_correct_mean_predictions_1 (641 time steps)
# 9_incorrect_mean_predictions_1 (627 time steps)
# 7_overall_mean_predictions_2 (649 time steps)
# 8_correct_mean_predictions_2 (642 time steps)
# 9_incorrect_mean_predictions_2 (649 time steps)
# 7_overall_mean_predictions_3 (649 time steps)
# 8_correct_mean_predictions_3 (643 time steps)
# 9_incorrect_mean_predictions_3 (649 time steps)
# 7_overall_mean_predictions_4 (649 time steps)
# 8_correct_mean_predictions_4 (642 time steps)
# 9_incorrect_mean_predictions_4 (649 time steps)
# 7_overall_mean_predictions_5 (649 time steps)
# 8_correct_mean_predictions_5 (641 time steps)
# 9_incorrect_mean_predictions_5 (649 time steps)
# 7_overall_mean_predictions_6 (649 time steps)
# 8_correct_mean_predictions_6 (642 time steps)
# 9_incorrect_mean_predictions_6 (649 time steps)
# 7_overall_mean_predictions_7 (649 time steps)
# 8_correct_mean_predictions_7 (642 time steps)
# 9_incorrect_mean_predictions_7 (649 time steps)
# 7_overall_mean_predictions_8 (649 time steps)
# 8_correct_mean_predictions_8 (642 time steps)
# 9_incorrect_mean_predictions_8 (649 time steps)
# 7_overall_mean_predictions_9 (649 time steps)
# 8_correct_mean_predictions_9 (643 time steps)
# 9_incorrect_mean_predictions_9 (649 time steps)
# 7_overall_mean_predictions_10 (649 time steps)
# 8_correct_mean_predictions_10 (642 time steps)
# 9_incorrect_mean_predictions_10 (649 time steps)
# 7_overall_mean_predictions_11 (649 time steps)
# 8_correct_mean_predictions_11 (644 time steps)
# 9_incorrect_mean_predictions_11 (649 time steps)
# 7_overall_mean_predictions_12 (649 time steps)
# 8_correct_mean_predictions_12 (644 time steps)
# 9_incorrect_mean_predictions_12 (649 time steps)
# 7_overall_mean_predictions_13 (649 time steps)
# 8_correct_mean_predictions_13 (644 time steps)
# 9_incorrect_mean_predictions_13 (649 time steps)
# 7_overall_mean_predictions_14 (649 time steps)
# 8_correct_mean_predictions_14 (642 time steps)
# 9_incorrect_mean_predictions_14 (649 time steps)
# 7_overall_mean_predictions_15 (649 time steps)
# 8_correct_mean_predictions_15 (646 time steps)
# 9_incorrect_mean_predictions_15 (649 time steps)
#
#
# ### TFAgentsPPOAgent ###
#
#
# ## scalars ##
#
#
# 1_win_percentage (649 time steps)
# 2_score (649 time steps)
# 7_valid_rate (649 time steps)
# 5_predictor_loss (582 time steps)
# 3_predictor_acc (582 time steps)
# 6_prediction_differences (649 time steps)
# 4_predictor_acc_real (649 time steps)
# 7_overall_mean_predictions_0 (649 time steps)
# 8_correct_mean_predictions_0 (649 time steps)
# 9_incorrect_mean_predictions_0 (649 time steps)
# 7_overall_mean_predictions_1 (649 time steps)
# 8_correct_mean_predictions_1 (649 time steps)
# 9_incorrect_mean_predictions_1 (637 time steps)
# 7_overall_mean_predictions_2 (649 time steps)
# 8_correct_mean_predictions_2 (649 time steps)
# 9_incorrect_mean_predictions_2 (649 time steps)
# 7_overall_mean_predictions_3 (649 time steps)
# 8_correct_mean_predictions_3 (649 time steps)
# 9_incorrect_mean_predictions_3 (649 time steps)
# 7_overall_mean_predictions_4 (649 time steps)
# 8_correct_mean_predictions_4 (649 time steps)
# 9_incorrect_mean_predictions_4 (649 time steps)
# 7_overall_mean_predictions_5 (649 time steps)
# 8_correct_mean_predictions_5 (649 time steps)
# 9_incorrect_mean_predictions_5 (649 time steps)
# 7_overall_mean_predictions_6 (649 time steps)
# 8_correct_mean_predictions_6 (649 time steps)
# 9_incorrect_mean_predictions_6 (649 time steps)
# 7_overall_mean_predictions_7 (649 time steps)
# 8_correct_mean_predictions_7 (649 time steps)
# 9_incorrect_mean_predictions_7 (649 time steps)
# 7_overall_mean_predictions_8 (649 time steps)
# 8_correct_mean_predictions_8 (649 time steps)
# 9_incorrect_mean_predictions_8 (649 time steps)
# 7_overall_mean_predictions_9 (649 time steps)
# 8_correct_mean_predictions_9 (649 time steps)
# 9_incorrect_mean_predictions_9 (649 time steps)
# 7_overall_mean_predictions_10 (649 time steps)
# 8_correct_mean_predictions_10 (649 time steps)
# 9_incorrect_mean_predictions_10 (649 time steps)
# 7_overall_mean_predictions_11 (649 time steps)
# 8_correct_mean_predictions_11 (649 time steps)
# 9_incorrect_mean_predictions_11 (649 time steps)
# 7_overall_mean_predictions_12 (649 time steps)
# 8_correct_mean_predictions_12 (649 time steps)
# 9_incorrect_mean_predictions_12 (649 time steps)
# 7_overall_mean_predictions_13 (649 time steps)
# 8_correct_mean_predictions_13 (649 time steps)
# 9_incorrect_mean_predictions_13 (649 time steps)
# 7_overall_mean_predictions_14 (649 time steps)
# 8_correct_mean_predictions_14 (649 time steps)
# 9_incorrect_mean_predictions_14 (649 time steps)
# 7_overall_mean_predictions_15 (649 time steps)
# 8_correct_mean_predictions_15 (648 time steps)
# 9_incorrect_mean_predictions_15 (649 time steps)

# %% [markdown]
# ### Plot Score
#
# ToDo: matplotlib to tix

# %%
plot_scalar(train_vs_old_data, summary_name='2_score', save_plot=True, ylim=(10,300),ylabel='score', smoothing=True, plot_original=True, smoothing_factor=0.99)
# Out:
# Agents that have data for metric `2_score`:  ['TFAgentsPPOAgent']
# 2969 3000

# %%
get_average_value(train_vs_old_data, summary_name='2_score', time_range=[59000,60000])
# Out:
# Agents that have data for metric `2_score`:  ['TFAgentsPPOAgent']
# 51
# TFAgentsPPOAgent: 189.83333333333334

# %% [markdown]
# ### Plot Accuracy / Mean Prediction

# %%
plot_scalar(train_vs_old_data, summary_name='4_predictor_acc_real', save_plot=True, ylim= [0.35, 0.6],ylabel="accuracy", smoothing=True, plot_original=True, smoothing_factor=0.99)
# Out:
# Agents that have data for metric `4_predictor_acc_real`:  ['TFAgentsPPOAgent']
# 2969 3000

# %% [markdown]
# ### Evaluation

# %% [markdown]
# With overfitted Model

# %%
plot_scalar(evaluate_vs_current_data, summary_name='2_score', plot_title="evaluation_current", save_plot=True,ylim = [0, 200],ylabel='score', smoothing=True, plot_original=False, smoothing_factor=0.99)
# Out:
# Agents that have data for metric `2_score`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 1683 1700
# 1683 1700
# 1683 1700
# 1683 1700

# %%
get_average_value(evaluate_vs_current_data, summary_name='2_score', time_range=[30000,40000])
# Out:
# Agents that have data for metric `2_score`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 201
# AverageRandomPlayer: 16.84328358208955
# 201
# RuleBasedAgent: 87.86567164179104
# 201
# RuleBasedAgentPredictor: 133.0497512437811
# 201
# TFAgentsPPOAgent: 150.78855721393035

# %%
plot_scalar(evaluate_vs_current_data, summary_name='1_win_percentage', plot_title="evaluation_current_win", save_plot=True,ylim = [0, 0.7], ylabel='score', smoothing=True, plot_original=False, smoothing_factor=0.99)
# Out:
# Agents that have data for metric `1_win_percentage`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 1683 1700
# 1683 1700
# 1683 1700
# 1683 1700

# %%
get_average_value(evaluate_vs_current_data, summary_name='1_win_percentage')
# Out:
# Agents that have data for metric `1_win_percentage`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 1700
# AverageRandomPlayer: 0.059645659434883036
# 1700
# RuleBasedAgent: 0.1692843167089364
# 1700
# RuleBasedAgentPredictor: 0.31229411945842644
# 1700
# TFAgentsPPOAgent: 0.45877591134870754

# %% [markdown]
# #### not overfitted

# %%
plot_scalar(evaluate_vs_old_data, summary_name='2_score', plot_title="evaluation_old", save_plot=True,ylim = [0, 200], ylabel='score', smoothing=True, plot_original=False, smoothing_factor=0.99)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1b8d84b57b6e> in <module>
# ----> 1 plot_scalar(evaluate_vs_old_data, summary_name='2_score', plot_title="evaluation_old", save_plot=True,ylim = [0, 200], ylabel='score', smoothing=True, plot_original=False, smoothing_factor=0.99)
#
# NameError: name 'evaluate_vs_old_data' is not defined

# %%
plot_scalar(evaluate_vs_old_data_2, summary_name='2_score', plot_title="evaluation_old", save_plot=True,ylim = [0, 200], ylabel='score', smoothing=True, plot_original=False, smoothing_factor=0.99)
# Out:
# Agents that have data for metric `2_score`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 641 649
# 421 426
# 641 649
# 641 649

# %%
get_average_value(evaluate_vs_old_data, summary_name='2_score', time_range=[30000,40000])
# Out:
# Agents that have data for metric `2_score`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 501
# AverageRandomPlayer: 17.005988023952096
# 501
# RuleBasedAgent: 84.83433133732535
# 501
# RuleBasedAgentPredictor: 131.79441117764472
# 501
# TFAgentsPPOAgent: 154.74950099800398

# %%
plot_scalar(evaluate_vs_old_data, summary_name='1_win_percentage', plot_title="evaluation_old_win", save_plot=True,ylim = [0, 0.6], ylabel='score', smoothing=True, plot_original=False, smoothing_factor=0.99)
# Out:
# Agents that have data for metric `1_win_percentage`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 2229 2252
# 2229 2252
# 2229 2252
# 2229 2252

# %%
get_average_value(evaluate_vs_old_data, summary_name='1_win_percentage')
# Out:
# Agents that have data for metric `1_win_percentage`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 501
# AverageRandomPlayer: 0.05299401295904866
# 501
# RuleBasedAgent: 0.16616766763007093
# 501
# RuleBasedAgentPredictor: 0.3181636742503938
# 501
# TFAgentsPPOAgent: 0.4626746522392817

# %%
get_variance(evaluate_vs_old_data, summary_name='2_score', time_range=[15000,40000])
# Out:
# Agents that have data for metric `2_score`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 1251
# AverageRandomPlayer: 412.42261091206973
# 1251
# RuleBasedAgent: 441.4184693811697
# 1251
# RuleBasedAgentPredictor: 487.9049521374108
# 1251
# TFAgentsPPOAgent: 514.8086138603106

# %%
get_variance(evaluate_vs_current_data, summary_name='2_score', time_range=[15000,40000])
# Out:
# Agents that have data for metric `2_score`:  ['AverageRandomPlayer', 'RuleBasedAgent', 'RuleBasedAgentPredictor', 'TFAgentsPPOAgent']
# 951
# AverageRandomPlayer: 457.095700911432
# 951
# RuleBasedAgent: 443.47316124152894
# 951
# RuleBasedAgentPredictor: 442.9511439062982
# 951
# TFAgentsPPOAgent: 541.7080432241893

# %%
def get_average_value(data, summary_name, time_range=[10000,60000]):
              
    agents = data.keys()
             
            
    agents_with_data = [agent for agent in agents if summary_name in data[agent]['scalars'].keys()]
    print(f'Agents that have data for metric `{summary_name}`: ', agents_with_data)
    
    for index, agent in enumerate(agents_with_data):
        agent_data = data[agent]['scalars'][summary_name]
        time_ranged_data = [x[1] for x in agent_data if time_range[0] <= x[0] <= time_range[1]]
        print(len(time_ranged_data))
        mean_value = np.mean(time_ranged_data)
        
        print(f'{agent}: {mean_value}')

# %%
def get_variance(data, summary_name, time_range=[0,60000]):
              
    agents = data.keys()
             
            
    agents_with_data = [agent for agent in agents if summary_name in data[agent]['scalars'].keys()]
    print(f'Agents that have data for metric `{summary_name}`: ', agents_with_data)
    
    for index, agent in enumerate(agents_with_data):
        agent_data = data[agent]['scalars'][summary_name]
        time_ranged_data = [x[1] for x in agent_data if time_range[0] <= x[0] <= time_range[1]]
        print(len(time_ranged_data))
        mean_value = np.var(time_ranged_data)
        
        print(f'{agent}: {mean_value}')

# %% [markdown]
# ToDos:
#     * Smooting issue
#     * Line Thickness

# %% [markdown]
# Notes:
#     * Include Winpercentage
